# %%
stvar = {'slika' : 0}
imena = [stvar]
imena
# Out:
# [{'slika': 0}]

# %%
imena
# Out:
# []

# %%
predmeti = []
ceno = []
pari = []
for vrstica in open('zapisnik.txt', encoding = 'UTF 8'):
    predmet, ime, cena = vrstica.split(',')
    predmeti.append(predmet)
    ceno.append(cena)
    for pari in zip(predmeti, ceno):
        print(pari)
# Out:
# ('slika', '31\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('kip', '86\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('kip', '86\n')
# ('kip', '90\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('kip', '86\n')
# ('kip', '90\n')
# ('kip', '92\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('kip', '86\n')
# ('kip', '90\n')
# ('kip', '92\n')
# ('kip', '94\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('kip', '86\n')
# ('kip', '90\n')
# ('kip', '92\n')
# ('kip', '94\n')
# ('kip', '97\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('kip', '86\n')
# ('kip', '90\n')
# ('kip', '92\n')
# ('kip', '94\n')
# ('kip', '97\n')
# ('kip', '98\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('kip', '86\n')
# ('kip', '90\n')
# ('kip', '92\n')
# ('kip', '94\n')
# ('kip', '97\n')
# ('kip', '98\n')
# ('kip', '99\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('kip', '86\n')
# ('kip', '90\n')
# ('kip', '92\n')
# ('kip', '94\n')
# ('kip', '97\n')
# ('kip', '98\n')
# ('kip', '99\n')
# ('kip', '100\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('kip', '86\n')
# ('kip', '90\n')
# ('kip', '92\n')
# ('kip', '94\n')
# ('kip', '97\n')
# ('kip', '98\n')
# ('kip', '99\n')
# ('kip', '100\n')
# ('kip', '103\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('kip', '86\n')
# ('kip', '90\n')
# ('kip', '92\n')
# ('kip', '94\n')
# ('kip', '97\n')
# ('kip', '98\n')
# ('kip', '99\n')
# ('kip', '100\n')
# ('kip', '103\n')
# ('kip', '107\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('kip', '86\n')
# ('kip', '90\n')
# ('kip', '92\n')
# ('kip', '94\n')
# ('kip', '97\n')
# ('kip', '98\n')
# ('kip', '99\n')
# ('kip', '100\n')
# ('kip', '103\n')
# ('kip', '107\n')
# ('čajnik', '15\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('kip', '86\n')
# ('kip', '90\n')
# ('kip', '92\n')
# ('kip', '94\n')
# ('kip', '97\n')
# ('kip', '98\n')
# ('kip', '99\n')
# ('kip', '100\n')
# ('kip', '103\n')
# ('kip', '107\n')
# ('čajnik', '15\n')
# ('srebrn jedilni servis', '27\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('kip', '86\n')
# ('kip', '90\n')
# ('kip', '92\n')
# ('kip', '94\n')
# ('kip', '97\n')
# ('kip', '98\n')
# ('kip', '99\n')
# ('kip', '100\n')
# ('kip', '103\n')
# ('kip', '107\n')
# ('čajnik', '15\n')
# ('srebrn jedilni servis', '27\n')
# ('srebrn jedilni servis', '30\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('kip', '86\n')
# ('kip', '90\n')
# ('kip', '92\n')
# ('kip', '94\n')
# ('kip', '97\n')
# ('kip', '98\n')
# ('kip', '99\n')
# ('kip', '100\n')
# ('kip', '103\n')
# ('kip', '107\n')
# ('čajnik', '15\n')
# ('srebrn jedilni servis', '27\n')
# ('srebrn jedilni servis', '30\n')
# ('srebrn jedilni servis', '35\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('kip', '86\n')
# ('kip', '90\n')
# ('kip', '92\n')
# ('kip', '94\n')
# ('kip', '97\n')
# ('kip', '98\n')
# ('kip', '99\n')
# ('kip', '100\n')
# ('kip', '103\n')
# ('kip', '107\n')
# ('čajnik', '15\n')
# ('srebrn jedilni servis', '27\n')
# ('srebrn jedilni servis', '30\n')
# ('srebrn jedilni servis', '35\n')
# ('srebrn jedilni servis', '39\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('kip', '86\n')
# ('kip', '90\n')
# ('kip', '92\n')
# ('kip', '94\n')
# ('kip', '97\n')
# ('kip', '98\n')
# ('kip', '99\n')
# ('kip', '100\n')
# ('kip', '103\n')
# ('kip', '107\n')
# ('čajnik', '15\n')
# ('srebrn jedilni servis', '27\n')
# ('srebrn jedilni servis', '30\n')
# ('srebrn jedilni servis', '35\n')
# ('srebrn jedilni servis', '39\n')
# ('srebrn jedilni servis', '40\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ...
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('kip', '86\n')
# ('kip', '90\n')
# ('kip', '92\n')
# ('kip', '94\n')
# ('kip', '97\n')
# ('kip', '98\n')
# ('kip', '99\n')
# ('kip', '100\n')
# ('kip', '103\n')
# ('kip', '107\n')
# ('čajnik', '15\n')
# ('srebrn jedilni servis', '27\n')
# ('srebrn jedilni servis', '30\n')
# ('srebrn jedilni servis', '35\n')
# ('srebrn jedilni servis', '39\n')
# ('srebrn jedilni servis', '40\n')
# ('srebrn jedilni servis', '45\n')
# ('srebrn jedilni servis', '47\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('kip', '86\n')
# ('kip', '90\n')
# ('kip', '92\n')
# ('kip', '94\n')
# ('kip', '97\n')
# ('kip', '98\n')
# ('kip', '99\n')
# ('kip', '100\n')
# ('kip', '103\n')
# ('kip', '107\n')
# ('čajnik', '15\n')
# ('srebrn jedilni servis', '27\n')
# ('srebrn jedilni servis', '30\n')
# ('srebrn jedilni servis', '35\n')
# ('srebrn jedilni servis', '39\n')
# ('srebrn jedilni servis', '40\n')
# ('srebrn jedilni servis', '45\n')
# ('srebrn jedilni servis', '47\n')
# ('srebrn jedilni servis', '49\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('kip', '86\n')
# ('kip', '90\n')
# ('kip', '92\n')
# ('kip', '94\n')
# ('kip', '97\n')
# ('kip', '98\n')
# ('kip', '99\n')
# ('kip', '100\n')
# ('kip', '103\n')
# ('kip', '107\n')
# ('čajnik', '15\n')
# ('srebrn jedilni servis', '27\n')
# ('srebrn jedilni servis', '30\n')
# ('srebrn jedilni servis', '35\n')
# ('srebrn jedilni servis', '39\n')
# ('srebrn jedilni servis', '40\n')
# ('srebrn jedilni servis', '45\n')
# ('srebrn jedilni servis', '47\n')
# ('srebrn jedilni servis', '49\n')
# ('srebrn jedilni servis', '53\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('kip', '86\n')
# ('kip', '90\n')
# ('kip', '92\n')
# ('kip', '94\n')
# ('kip', '97\n')
# ('kip', '98\n')
# ('kip', '99\n')
# ('kip', '100\n')
# ('kip', '103\n')
# ('kip', '107\n')
# ('čajnik', '15\n')
# ('srebrn jedilni servis', '27\n')
# ('srebrn jedilni servis', '30\n')
# ('srebrn jedilni servis', '35\n')
# ('srebrn jedilni servis', '39\n')
# ('srebrn jedilni servis', '40\n')
# ('srebrn jedilni servis', '45\n')
# ('srebrn jedilni servis', '47\n')
# ('srebrn jedilni servis', '49\n')
# ('srebrn jedilni servis', '53\n')
# ('srebrn jedilni servis', '55\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('kip', '86\n')
# ('kip', '90\n')
# ('kip', '92\n')
# ('kip', '94\n')
# ('kip', '97\n')
# ('kip', '98\n')
# ('kip', '99\n')
# ('kip', '100\n')
# ('kip', '103\n')
# ('kip', '107\n')
# ('čajnik', '15\n')
# ('srebrn jedilni servis', '27\n')
# ('srebrn jedilni servis', '30\n')
# ('srebrn jedilni servis', '35\n')
# ('srebrn jedilni servis', '39\n')
# ('srebrn jedilni servis', '40\n')
# ('srebrn jedilni servis', '45\n')
# ('srebrn jedilni servis', '47\n')
# ('srebrn jedilni servis', '49\n')
# ('srebrn jedilni servis', '53\n')
# ('srebrn jedilni servis', '55\n')
# ('srebrn jedilni servis', '58\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('kip', '86\n')
# ('kip', '90\n')
# ('kip', '92\n')
# ('kip', '94\n')
# ('kip', '97\n')
# ('kip', '98\n')
# ('kip', '99\n')
# ('kip', '100\n')
# ('kip', '103\n')
# ('kip', '107\n')
# ('čajnik', '15\n')
# ('srebrn jedilni servis', '27\n')
# ('srebrn jedilni servis', '30\n')
# ('srebrn jedilni servis', '35\n')
# ('srebrn jedilni servis', '39\n')
# ('srebrn jedilni servis', '40\n')
# ('srebrn jedilni servis', '45\n')
# ('srebrn jedilni servis', '47\n')
# ('srebrn jedilni servis', '49\n')
# ('srebrn jedilni servis', '53\n')
# ('srebrn jedilni servis', '55\n')
# ('srebrn jedilni servis', '58\n')
# ('srebrn jedilni servis', '59\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('kip', '86\n')
# ('kip', '90\n')
# ('kip', '92\n')
# ('kip', '94\n')
# ('kip', '97\n')
# ('kip', '98\n')
# ('kip', '99\n')
# ('kip', '100\n')
# ('kip', '103\n')
# ('kip', '107\n')
# ('čajnik', '15\n')
# ('srebrn jedilni servis', '27\n')
# ('srebrn jedilni servis', '30\n')
# ('srebrn jedilni servis', '35\n')
# ('srebrn jedilni servis', '39\n')
# ('srebrn jedilni servis', '40\n')
# ('srebrn jedilni servis', '45\n')
# ('srebrn jedilni servis', '47\n')
# ('srebrn jedilni servis', '49\n')
# ('srebrn jedilni servis', '53\n')
# ('srebrn jedilni servis', '55\n')
# ('srebrn jedilni servis', '58\n')
# ('srebrn jedilni servis', '59\n')
# ('srebrn jedilni servis', '62\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('kip', '86\n')
# ('kip', '90\n')
# ('kip', '92\n')
# ('kip', '94\n')
# ('kip', '97\n')
# ('kip', '98\n')
# ('kip', '99\n')
# ('kip', '100\n')
# ('kip', '103\n')
# ('kip', '107\n')
# ('čajnik', '15\n')
# ('srebrn jedilni servis', '27\n')
# ('srebrn jedilni servis', '30\n')
# ('srebrn jedilni servis', '35\n')
# ('srebrn jedilni servis', '39\n')
# ('srebrn jedilni servis', '40\n')
# ('srebrn jedilni servis', '45\n')
# ('srebrn jedilni servis', '47\n')
# ('srebrn jedilni servis', '49\n')
# ('srebrn jedilni servis', '53\n')
# ('srebrn jedilni servis', '55\n')
# ('srebrn jedilni servis', '58\n')
# ('srebrn jedilni servis', '59\n')
# ('srebrn jedilni servis', '62\n')
# ('srebrn jedilni servis', '63\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('kip', '86\n')
# ('kip', '90\n')
# ('kip', '92\n')
# ('kip', '94\n')
# ('kip', '97\n')
# ('kip', '98\n')
# ('kip', '99\n')
# ('kip', '100\n')
# ('kip', '103\n')
# ('kip', '107\n')
# ('čajnik', '15\n')
# ('srebrn jedilni servis', '27\n')
# ('srebrn jedilni servis', '30\n')
# ('srebrn jedilni servis', '35\n')
# ('srebrn jedilni servis', '39\n')
# ('srebrn jedilni servis', '40\n')
# ('srebrn jedilni servis', '45\n')
# ('srebrn jedilni servis', '47\n')
# ('srebrn jedilni servis', '49\n')
# ('srebrn jedilni servis', '53\n')
# ('srebrn jedilni servis', '55\n')
# ('srebrn jedilni servis', '58\n')
# ('srebrn jedilni servis', '59\n')
# ('srebrn jedilni servis', '62\n')
# ('srebrn jedilni servis', '63\n')
# ('perzijska preproga', '16\n')
# ('slika', '31\n')
# ('slika', '33\n')
# ('slika', '35\n')
# ('slika', '37\n')
# ('slika', '40\n')
# ('slika', '45\n')
# ('pozlačen dežnik', '29\n')
# ('Meldrumove vaze', '44\n')
# ('Meldrumove vaze', '46\n')
# ('Meldrumove vaze', '48\n')
# ('Meldrumove vaze', '53\n')
# ('Meldrumove vaze', '57\n')
# ('Meldrumove vaze', '60\n')
# ('Meldrumove vaze', '61\n')
# ('Meldrumove vaze', '63\n')
# ('Meldrumove vaze', '67\n')
# ('Meldrumove vaze', '71\n')
# ('Meldrumove vaze', '76\n')
# ('Meldrumove vaze', '78\n')
# ('skodelice', '50\n')
# ('skodelice', '55\n')
# ('skodelice', '60\n')
# ('skodelice', '61\n')
# ('skodelice', '62\n')
# ('skodelice', '65\n')
# ('skodelice', '68\n')
# ('skodelice', '70\n')
# ('skodelice', '74\n')
# ('skodelice', '76\n')
# ('skodelice', '80\n')
# ('skodelice', '83\n')
# ('kip', '30\n')
# ('kip', '32\n')
# ('kip', '37\n')
# ('kip', '39\n')
# ('kip', '43\n')
# ('kip', '44\n')
# ('kip', '45\n')
# ('kip', '50\n')
# ('kip', '53\n')
# ('kip', '55\n')
# ('kip', '58\n')
# ('kip', '61\n')
# ('kip', '63\n')
# ('kip', '68\n')
# ('kip', '72\n')
# ('kip', '76\n')
# ('kip', '77\n')
# ('kip', '81\n')
# ('kip', '85\n')
# ('kip', '86\n')
# ('kip', '90\n')
# ('kip', '92\n')
# ('kip', '94\n')
# ('kip', '97\n')
# ('kip', '98\n')
# ('kip', '99\n')
# ('kip', '100\n')
# ('kip', '103\n')
# ('kip', '107\n')
# ('čajnik', '15\n')
# ('srebrn jedilni servis', '27\n')
# ('srebrn jedilni servis', '30\n')
# ('srebrn jedilni servis', '35\n')
# ('srebrn jedilni servis', '39\n')
# ('srebrn jedilni servis', '40\n')
# ('srebrn jedilni servis', '45\n')
# ('srebrn jedilni servis', '47\n')
# ('srebrn jedilni servis', '49\n')
# ('srebrn jedilni servis', '53\n')
# ('srebrn jedilni servis', '55\n')
# ('srebrn jedilni servis', '58\n')
# ('srebrn jedilni servis', '59\n')
# ('srebrn jedilni servis', '62\n')
# ('srebrn jedilni servis', '63\n')
# ('perzijska preproga', '16\n')
# ('perzijska preproga', '21\n')
